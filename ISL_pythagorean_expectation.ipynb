# %%
import pandas as pd

# %%
df=pd.read_csv("D:\\FootballAnalytics\\ISL_league_stage.csv")

# %%
df.head()
# Out:
#                  team  goals     xG  goals_conceded    xGA  shots  \
# 0  ATK Mohun Bagan FC     37  32.22              26  22.84    282
# 1        Bengaluru FC     32  26.84              27  19.97    214
# 2       Chennaiyin FC     17  22.03              35  33.32    211
# 3              FC Goa     29  29.37              35  23.97    248
# 4        Hyderabad FC     43  29.25              23  22.62    237
#
#    shots_against  xPoints  xG_first_half  xGA_first_half  xG_second_half  \
# 0            275     33.0          13.37           11.01           18.86
# 1            207     31.8          13.58           10.48           13.31
# 2            283     23.9          10.87           19.36           11.18
# 3            200     27.7          15.81           10.84           13.55
# 4            210     27.4          14.08           10.14           15.14
#
#    xGA_second_half  xG_Open_Play  xGA_Open_Play  xG_Set_Play  xGA_Set_Play  \
# ...

# %%
df['pyth']=df['goals']**1.22777/(df['goals_conceded']**1.072388+df['goals']**1.072388)* 2.499973 * 20

# %%
df.head()
# Out:
#                  team  goals     xG  goals_conceded    xGA  shots  \
# 0  ATK Mohun Bagan FC     37  32.22              26  22.84    282
# 1        Bengaluru FC     32  26.84              27  19.97    214
# 2       Chennaiyin FC     17  22.03              35  33.32    211
# 3              FC Goa     29  29.37              35  23.97    248
# 4        Hyderabad FC     43  29.25              23  22.62    237
#
#    shots_against  xPoints  xG_first_half  xGA_first_half  ...  \
# 0            275     33.0          13.37           11.01  ...
# 1            207     31.8          13.58           10.48  ...
# 2            283     23.9          10.87           19.36  ...
# 3            200     27.7          15.81           10.84  ...
# 4            210     27.4          14.08           10.14  ...
#
#    xGA_second_half  xG_Open_Play  xGA_Open_Play  xG_Set_Play  xGA_Set_Play  \
# 0            11.82         15.32          12.46         4.79          5.79
# ...

# %%
df
# Out:
#                    team  goals     xG  goals_conceded    xGA  shots  \
# 0    ATK Mohun Bagan FC     37  32.22              26  22.84    282
# 1          Bengaluru FC     32  26.84              27  19.97    214
# 2         Chennaiyin FC     17  22.03              35  33.32    211
# 3                FC Goa     29  29.37              35  23.97    248
# 4          Hyderabad FC     43  29.25              23  22.62    237
# 5            Jamshedpur     42  29.16              21  18.35    274
# 6    Kerala Blasters FC     34  25.17              24  23.26    224
# 7        Mumbai City FC     36  28.21              31  26.29    245
# 8   Northeast United FC     25  25.39              43  40.96    250
# 9             Odisha FC     31  26.01              43  30.38    219
# 10       SC East Bengal     18  17.10              36  28.79    227
#
#     shots_against  xPoints  xG_first_half  xGA_first_half  ...  \
# 0             275     33.0          13.37           11.01  ...
# ...
